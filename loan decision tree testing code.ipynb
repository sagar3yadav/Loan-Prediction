# %%
#importing all requried libraries..
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing loan dataset
loan = pd.read_csv('loan_data.csv')

# %%
# checking the data is imported or not  by sample function.
loan.sample(14)
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 5023              1         credit_card    0.1287       235.44
# 1092              1    home_improvement    0.0945       192.06
# 8255              0  debt_consolidation    0.1355       394.78
# 1395              1           all_other    0.1304       384.34
# 6865              1           all_other    0.1183        99.41
# 7073              1  debt_consolidation    0.0751       279.99
# 1872              1         credit_card    0.1632       529.71
# 2845              1           all_other    0.0963       144.43
# 6371              1           all_other    0.0774       312.19
# 1097              1           all_other    0.1324       253.58
# 7767              0  debt_consolidation    0.1091       114.44
# 1466              1      small_business    0.1272       268.48
# 6376              1    home_improvement    0.1357       203.82
# 4977              1         credit_card    0.0740        65.23
#
# ...

# %%
#count values in loan.rec column
loan['pub.rec'].value_counts()
# Out:
# 0    9019
# 1     533
# 2      19
# 3       5
# 5       1
# 4       1
# Name: pub.rec, dtype: int64

# %%
# check for null values in pub.rec column
loan['pub.rec'].isnull().value_counts()
# Out:
# False    9578
# Name: pub.rec, dtype: int64

# %%
#count of people who paid or not
loan['not.fully.paid'].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %%
#percentage of not fully paid that is true
8045/9578*100
# Out:
# 83.99457089162664

# %%
#not fully paid that is False
1533/9578*100
# Out:
# 16.005429108373356

# %%
#distributing the data with true and false credit policy
zero = loan[loan['credit.policy'] == 0]
one = loan[loan['credit.policy'] == 1]

# %%
#plotting a histogram of both True and False
plt.hist(zero.fico , bins=30,alpha=0.5,color='b')
plt.hist(one.fico , bins=30,alpha=0.1,color='r')
plt.show()

# %%
#Histogam of peoples with fico score who has True credit policy
plt.hist(one.fico , bins=30,alpha=0.5)
# Out:
# (array([  3.,   1.,   1.,  10., 102., 112., 258., 108., 121., 102., 215.,
#         116.,  91., 163.,  74.,  60., 122.,  57.,  44.,  44.,  15.,   7.,
#           8.,  13.,   3.,   2.,   3.,   3.,   1.,   9.]),
#  array([612. , 618.5, 625. , 631.5, 638. , 644.5, 651. , 657.5, 664. ,
#         670.5, 677. , 683.5, 690. , 696.5, 703. , 709.5, 716. , 722.5,
#         729. , 735.5, 742. , 748.5, 755. , 761.5, 768. , 774.5, 781. ,
#         787.5, 794. , 800.5, 807. ]),
#  <a list of 30 Patch objects>)

# %%
##Histogam of peoples with fico score who has False or 0 credit policy
plt.hist(loan.fico , bins=30)
# Out:
# (array([  3.,   1.,   8.,   5., 214., 131., 541., 438., 395., 963., 548.,
#         974., 472., 839., 424., 388., 691., 313., 560., 258., 451., 142.,
#         158., 258.,  85., 173.,  55.,  78.,   6.,   6.]),
#  array([612.        , 619.16666667, 626.33333333, 633.5       ,
#         640.66666667, 647.83333333, 655.        , 662.16666667,
#         669.33333333, 676.5       , 683.66666667, 690.83333333,
#         698.        , 705.16666667, 712.33333333, 719.5       ,
#         726.66666667, 733.83333333, 741.        , 748.16666667,
#         755.33333333, 762.5       , 769.66666667, 776.83333333,
#         784.        , 791.16666667, 798.33333333, 805.5       ,
#         812.66666667, 819.83333333, 827.        ]),
#  <a list of 30 Patch objects>)

# %%
#Histogam of peoples with fico score who has True(0) and False(0) credit policy
plt.figure(figsize=(10,10))
loan[loan['credit.policy']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='Credit.Policy=1')
loan[loan['credit.policy']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='Credit.Policy=0')
plt.xlabel('Fico')
plt.legend()

# %%
#Histogam of peoples with fico score who has True(0) and False(0) not.fully.paid
plt.figure(figsize=(10,10))
loan[loan['not.fully.paid']==1]['fico'].hist(alpha=0.7,color='k',
                                              bins=35,label='Credit.Policy=1')
loan[loan['not.fully.paid']==0]['fico'].hist(alpha=0.5,color='g',
                                              bins=35,label='Credit.Policy=0')
plt.xlabel('Fico')
plt.legend()

# %%
#count plot of purpose and not not.fully.paid
plt.figure(figsize=(10,10))
sns.countplot(x = 'purpose',hue= 'not.fully.paid',data=loan,palette='Set1')
plt.xticks(rotation=70)
plt.rcParams['xtick.labelsize'] = 20

# %%
#Joint plot of fico and int.rate
sns.jointplot(x = 'fico' , y = 'int.rate', data=loan,kind='hex')
# Out:
# /home/sagar/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#lmplot fico and int.rate and with a 2 column of not.fully.paid and hue is credit.policy
sns.lmplot(x = 'fico' ,y = 'int.rate', data=loan, hue='credit.policy',col='not.fully.paid')
# Out:
# /home/sagar/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
loan.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
#pair plot 
plt.figure(figsize=(15,20))
sns.pairplot(x_vars='fico',y_vars='int.rate',data=loan,hue='not.fully.paid',size=10)
# Out:
# /home/sagar/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Decision tree algorithm..
#importing libraries for decision tree. 
from sklearn.model_selection import train_test_split

# %%
catvar =['purpose']

# %%
loan1.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  purpose_credit_card  purpose_debt_consolidation  \
# ...

# %%
#creating dummies of purpose to convert all valuse in 0 and 1 form
loan1 = pd.get_dummies(loan,columns=catvar,drop_first=True)

# %%
#X is feature data and y is label data
X = loan1.drop('not.fully.paid',axis = 1)
y = loan1['not.fully.paid']

# %%
# insert the data in below with a test size of 0.30 that means we test our model 30% data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.83      0.84      2423
#           1       0.22      0.24      0.23       451
#
# avg / total       0.76      0.74      0.75      2874

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2022  401]
#  [ 341  110]]

# %%
#total of TP and TN
2022+110
# Out:
# 2132

# %%
# accuracy of model is 74
2131/2874
# Out:
# 0.7414752957550452

# %%
#Random forest to imporve the accuracy

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)


rfc.fit(X_train,y_train)

predictions = rfc.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(y_test,predictions))

print(confusion_matrix(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.84      0.99      0.91      2423
#           1       0.31      0.02      0.04       451
#
# avg / total       0.76      0.84      0.78      2874
#
# [[2403   20]
#  [ 442    9]]

# %%
#Sum of TP and TN
2403+9
# Out:
# 2412

# %%
2412+442+20
# Out:
# 2874

# %%
#Accuracy has increased by 10 % 
2412/2874
# Out:
# 0.8392484342379958
